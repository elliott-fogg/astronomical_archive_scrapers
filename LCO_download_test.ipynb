# %%
import requests
import json
import urllib
import pandas as pd
import numpy as np

# %%
import requests
import json
import urllib
import pandas as pd
import numpy as np
base_url = "https://archive-api.lco.global/frames/?"
param_dict = {
    "start": "2016-02-01 00:00",
    "end": "2016-08-01 00:00",
    "public": "true",
    "SITEID": "coj",
    "TELID": "1m0a",
    "limit": 1000,
    "offset": 0
}
request_url = base_url + urllib.parse.urlencode(param_dict)
r = requests.get(url=request_url)
df = pd.DataFrame(r.json()["results"])
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 12
#       2 param_dict = {
#       3     "start": "2016-02-01 00:00",
#       4     "end": "2016-08-01 00:00",
#    (...)
#       9     "offset": 0
#      10 }
#      11 request_url = base_url + urllib.parse.urlencode(param_dict)
# ---> 12 r = requests.get(url=request_url)
#      13 df = pd.DataFrame(r.json()["results"])
#      14 print(df.columns)
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\archive-scrapers-v8Gk1KU5-py3.11\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\archive-scrapers-v8Gk1KU5-py3.11\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\archive-scrapers-v8Gk1KU5-py3.11\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\archive-scrapers-v8Gk1KU5-py3.11\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\archive-scrapers-v8Gk1KU5-py3.11\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\archive-scrapers-v8Gk1KU5-py3.11\Lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\archive-scrapers-v8Gk1KU5-py3.11\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\archive-scrapers-v8Gk1KU5-py3.11\Lib\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
r = requests.get(url=request_url)
r
# Out:
# <Response [200]>

# %%
r.status_code
# Out:
# 200

# %%
data = r.json()

# %%
data
# Out:
# {'count': 89054,
#  'next': 'https://archive-api.lco.global/frames/?SITEID=coj&TELID=1m0a&end=2016-08-01+00%3A00&limit=1000&offset=1000&public=true&start=2016-02-01+00%3A00',
#  'previous': None,
#  'results': [{'id': 4565855,
#    'basename': 'coj1m003-kb77-20160731-0300-d00',
#    'observation_date': '2016-07-31T22:23:39.951000Z',
#    'observation_day': '2016-07-31',
#    'proposal_id': 'calibrate',
#    'instrument_id': 'kb77',
#    'target_name': '',
#    'reduction_level': 0,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': 299.236,
#    'primary_optical_element': 'R',
#    'public_date': '2016-07-31T22:23:39.951000Z',
#    'configuration_type': 'DARK',
#    'observation_id': 88091929,
#    'request_id': None,
#    'version_set': [{'id': 20902118,
#      'key': 'pVCuzTZubTZ3Bhl7WWI3qRvn1eJVeI7N',
#      'md5': '92034d38d371c1f25c8dca59994661a8',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0300-d00.fits.fz?versionId=pVCuzTZubTZ3Bhl7WWI3qRvn1eJVeI7N&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=a516db356b808ab509bed8eac77f4a0db3cccc2c2d582c49fc564b71236e04fe',
#      'created': '2020-03-17T23:38:10.541599Z'},
#     {'id': 4901659,
#      'key': 'W7ij4PX3lzzTuVMjxOK6pY2NiY5lcoEl',
#      'md5': '56abcf89c116c9f3a8f5c93b4f1775b3',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0300-d00.fits.fz?versionId=W7ij4PX3lzzTuVMjxOK6pY2NiY5lcoEl&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=b2f74294347acace0bf0907f812450a443e44b9e2ec1851cc81ddac3230d06ef',
#      'created': '2016-08-16T10:46:28.825103Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0300-d00.fits.fz?versionId=pVCuzTZubTZ3Bhl7WWI3qRvn1eJVeI7N&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=a516db356b808ab509bed8eac77f4a0db3cccc2c2d582c49fc564b71236e04fe',
#    'filename': 'coj1m003-kb77-20160731-0300-d00.fits.fz',
#    'DATE_OBS': '2016-07-31T22:23:39.951000Z',
#    'DAY_OBS': '2016-07-31',
#    'PROPID': 'calibrate',
#    'INSTRUME': 'kb77',
#    'OBJECT': '',
#    'RLEVEL': 0,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': 299.236,
#    'FILTER': 'R',
#    'L1PUBDAT': '2016-07-31T22:23:39.951000Z',
#    'OBSTYPE': 'DARK',
#    'BLKUID': 88091929,
#    'REQNUM': None,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[58.67261764790169, -35.156675265068095],
#       [58.67315197643579, -35.42243921628618],
#       [58.34702098272599, -35.42243910923045],
#       [58.3475555722859, -35.15667515906027],
#       [58.67261764790169, -35.156675265068095]]]},
#    'related_frames': []},
#   {'id': 4565846,
#    'basename': 'coj1m003-kb77-20160731-0299-d00',
#    'observation_date': '2016-07-31T22:18:24.589000Z',
#    'observation_day': '2016-07-31',
#    'proposal_id': 'calibrate',
#    'instrument_id': 'kb77',
#    'target_name': '',
#    'reduction_level': 0,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': 299.24,
#    'primary_optical_element': 'R',
#    'public_date': '2016-07-31T22:18:24.589000Z',
#    'configuration_type': 'DARK',
#    'observation_id': 88091929,
#    'request_id': None,
#    'version_set': [{'id': 20902108,
#      'key': 'b8NWz5o9Kgl5v6U.MztOYhT0tNDA7JKg',
#      'md5': 'd3dfda989b77beb46e6e0a7437c66272',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0299-d00.fits.fz?versionId=b8NWz5o9Kgl5v6U.MztOYhT0tNDA7JKg&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=05c94c1bdff69bd10c1aeb25de1f619e238a1c0c06cb7a0c81b79b1ca0295c5a',
#      'created': '2020-03-17T23:38:06.075382Z'},
#     {'id': 4901647,
#      'key': 'nc7phvdLSyXJYsEQC1n5TgUvfkjCVL.H',
#      'md5': '36cd01f22e41274cd7fea903be93a931',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0299-d00.fits.fz?versionId=nc7phvdLSyXJYsEQC1n5TgUvfkjCVL.H&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=b7aa89a3e59bc8d8e5ef7a2de22413f3e0eb6cf361cf17a6799f18a89a1aa026',
#      'created': '2016-08-16T10:46:13.282967Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0299-d00.fits.fz?versionId=b8NWz5o9Kgl5v6U.MztOYhT0tNDA7JKg&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=05c94c1bdff69bd10c1aeb25de1f619e238a1c0c06cb7a0c81b79b1ca0295c5a',
#    'filename': 'coj1m003-kb77-20160731-0299-d00.fits.fz',
#    'DATE_OBS': '2016-07-31T22:18:24.589000Z',
#    'DAY_OBS': '2016-07-31',
#    'PROPID': 'calibrate',
#    'INSTRUME': 'kb77',
#    'OBJECT': '',
#    'RLEVEL': 0,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': 299.24,
#    'FILTER': 'R',
#    'L1PUBDAT': '2016-07-31T22:18:24.589000Z',
#    'OBSTYPE': 'DARK',
#    'BLKUID': 88091929,
#    'REQNUM': None,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[57.353864541210555, -35.15852425763221],
#       [57.354398918518605, -35.42428820880131],
#       [57.02826043881511, -35.424288101738256],
#       [57.0287950771728, -35.158524151617115],
#       [57.353864541210555, -35.15852425763221]]]},
#    'related_frames': []},
#   {'id': 4565776,
#    'basename': 'coj1m003-kb77-20160731-0298-d00',
#    'observation_date': '2016-07-31T22:13:09.198000Z',
#    'observation_day': '2016-07-31',
#    'proposal_id': 'calibrate',
#    'instrument_id': 'kb77',
#    'target_name': '',
#    'reduction_level': 0,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': 299.236,
#    'primary_optical_element': 'R',
#    'public_date': '2016-07-31T22:13:09.198000Z',
#    'configuration_type': 'DARK',
#    'observation_id': 88091929,
#    'request_id': None,
#    'version_set': [{'id': 20902107,
#      'key': 'Va1l_zpR9d2YgOhdPcS2qKspCJICjVl7',
#      'md5': '31f0db9f81028c6dc9cdea8f02bd08aa',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0298-d00.fits.fz?versionId=Va1l_zpR9d2YgOhdPcS2qKspCJICjVl7&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=feba687b49f4ccd84b20eec6130ddd699d900d9f187e237cef00346d6c3200b7',
#      'created': '2020-03-17T23:38:06.025341Z'},
#     {'id': 4901656,
#      'key': 'At45skLt2wCjixh3I.2BOLmiAAlN_org',
#      'md5': '03ab4f8f34e387495dd8fa6636529022',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0298-d00.fits.fz?versionId=At45skLt2wCjixh3I.2BOLmiAAlN_org&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=9bc0fcc7643f636982554f5bd950b04b541593a07b8aaca5c22a3de252a2d85a',
#      'created': '2016-08-16T10:46:26.156201Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0298-d00.fits.fz?versionId=Va1l_zpR9d2YgOhdPcS2qKspCJICjVl7&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=feba687b49f4ccd84b20eec6130ddd699d900d9f187e237cef00346d6c3200b7',
#    'filename': 'coj1m003-kb77-20160731-0298-d00.fits.fz',
#    'DATE_OBS': '2016-07-31T22:13:09.198000Z',
#    'DAY_OBS': '2016-07-31',
#    'PROPID': 'calibrate',
#    'INSTRUME': 'kb77',
#    'OBJECT': '',
#    'RLEVEL': 0,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': 299.236,
#    'FILTER': 'R',
#    'L1PUBDAT': '2016-07-31T22:13:09.198000Z',
#    'OBSTYPE': 'DARK',
#    'BLKUID': 88091929,
#    'REQNUM': None,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[56.0352646809177, -35.1603462503046],
#       [56.03579910629184, -35.426110201425416],
#       [55.709653249240354, -35.42611009435516],
#       [55.71018793568761, -35.16034614428234],
#       [56.0352646809177, -35.1603462503046]]]},
#    'related_frames': []},
#   {'id': 4565777,
#    'basename': 'coj1m003-kb77-20160731-0297-d00',
#    'observation_date': '2016-07-31T22:07:53.758000Z',
#    'observation_day': '2016-07-31',
#    'proposal_id': 'calibrate',
#    'instrument_id': 'kb77',
#    'target_name': '',
#    'reduction_level': 0,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': 299.237,
#    'primary_optical_element': 'R',
#    'public_date': '2016-07-31T22:07:53.758000Z',
#    'configuration_type': 'DARK',
#    'observation_id': 88091929,
#    'request_id': None,
#    'version_set': [{'id': 20902109,
#      'key': 't1PwRniEjF2P9qg.wyJbRZVJyrCP_9Jp',
#      'md5': 'dc412834790d3b9fd66cc8145873c4d9',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0297-d00.fits.fz?versionId=t1PwRniEjF2P9qg.wyJbRZVJyrCP_9Jp&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=e2fb92fdab6a0fbb91fcfa7424211289a5ed7f26612119f6e005bad1c3d342b6',
#      'created': '2020-03-17T23:38:06.361121Z'},
#     {'id': 4901644,
#      'key': '_79ef0DQFHWyKaLoBlEPBABSh2m9hu2Y',
#      'md5': 'db6ff325b5f3ebbdf4a338b425183184',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0297-d00.fits.fz?versionId=_79ef0DQFHWyKaLoBlEPBABSh2m9hu2Y&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=6ddf39514f0e92dcc3b77788905d86197a33aefd08b81bc811f671a1e957c275',
#      'created': '2016-08-16T10:46:07.850998Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0297-d00.fits.fz?versionId=t1PwRniEjF2P9qg.wyJbRZVJyrCP_9Jp&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=e2fb92fdab6a0fbb91fcfa7424211289a5ed7f26612119f6e005bad1c3d342b6',
#    'filename': 'coj1m003-kb77-20160731-0297-d00.fits.fz',
#    'DATE_OBS': '2016-07-31T22:07:53.758000Z',
#    'DAY_OBS': '2016-07-31',
#    'PROPID': 'calibrate',
#    'INSTRUME': 'kb77',
#    'OBJECT': '',
#    'RLEVEL': 0,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': 299.237,
#    'FILTER': 'R',
#    'L1PUBDAT': '2016-07-31T22:07:53.758000Z',
#    'OBSTYPE': 'DARK',
#    'BLKUID': 88091929,
#    'REQNUM': None,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[54.716141067008614, -35.162141243085266],
#       [54.716675539740784, -35.42790519415852],
#       [54.39052241401643, -35.427905087081164],
#       [54.391057147844855, -35.16214113705596],
#       [54.716141067008614, -35.162141243085266]]]},
#    'related_frames': []},
#   {'id': 4565697,
#    'basename': 'coj1m003-kb77-20160731-0296-d00',
#    'observation_date': '2016-07-31T22:02:38.295000Z',
#    'observation_day': '2016-07-31',
#    'proposal_id': 'calibrate',
#    'instrument_id': 'kb77',
#    'target_name': '',
#    'reduction_level': 0,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': 299.236,
#    'primary_optical_element': 'R',
#    'public_date': '2016-07-31T22:02:38.295000Z',
#    'configuration_type': 'DARK',
#    'observation_id': 88091929,
#    'request_id': None,
#    'version_set': [{'id': 20902112,
#      'key': 'VOF6UXxzmjUlA4sn3BgQvC_Do6H6vns9',
#      'md5': 'fc6ca405bfd4c44b6d85a71e469be61e',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0296-d00.fits.fz?versionId=VOF6UXxzmjUlA4sn3BgQvC_Do6H6vns9&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=8f873ac5335864045fb566168f05d31a3632524eabb657e2f002cb880403c984',
#      'created': '2020-03-17T23:38:06.635370Z'},
#     {'id': 4901638,
#      'key': 'wCFsbrVFed8F1oZ_q07CchwFpbkGqkDe',
#      'md5': '1ac5fda69c55f562cb19bab5be820166',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0296-d00.fits.fz?versionId=wCFsbrVFed8F1oZ_q07CchwFpbkGqkDe&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=5c823ac6a0a5450b1c3ecc0e01fd18d6b7a7a0e0321469054dc85375b38509dc',
#      'created': '2016-08-16T10:45:49.608974Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0296-d00.fits.fz?versionId=VOF6UXxzmjUlA4sn3BgQvC_Do6H6vns9&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=8f873ac5335864045fb566168f05d31a3632524eabb657e2f002cb880403c984',
#    'filename': 'coj1m003-kb77-20160731-0296-d00.fits.fz',
#    'DATE_OBS': '2016-07-31T22:02:38.295000Z',
#    'DAY_OBS': '2016-07-31',
#    'PROPID': 'calibrate',
#    'INSTRUME': 'kb77',
#    'OBJECT': '',
#    'RLEVEL': 0,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': 299.236,
#    'FILTER': 'R',
#    'L1PUBDAT': '2016-07-31T22:02:38.295000Z',
#    'OBSTYPE': 'DARK',
#    'BLKUID': 88091929,
#    'REQNUM': None,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[53.39417370386475, -35.163911435965346],
#       [53.39470822330477, -35.42967538699169],
#       [53.06854792870183, -35.42967527990732],
#       [53.06908270926091, -35.16391132992908],
#       [53.39417370386475, -35.163911435965346]]]},
#    'related_frames': []},
#   {'id': 4565694,
#    'basename': 'coj1m003-kb77-20160731-0295-d00',
#    'observation_date': '2016-07-31T21:57:24.347000Z',
#    'observation_day': '2016-07-31',
#    'proposal_id': 'calibrate',
#    'instrument_id': 'kb77',
#    'target_name': '',
#    'reduction_level': 0,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': 299.235,
#    'primary_optical_element': 'R',
#    'public_date': '2016-07-31T21:57:24.347000Z',
#    'configuration_type': 'DARK',
#    'observation_id': 88091929,
#    'request_id': None,
#    'version_set': [{'id': 20902087,
#      'key': '_Aki_Ka1hbXy_1Re5AarPxZzrS_rS1hp',
#      'md5': 'e6d96b500cebb0b62cf0cfe158e41a9a',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0295-d00.fits.fz?versionId=_Aki_Ka1hbXy_1Re5AarPxZzrS_rS1hp&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=8b629829a822ca2773cf6f687756a29d112e4b936c25d380f2adb77080043ed3',
#      'created': '2020-03-17T23:38:01.382399Z'},
#     {'id': 4901640,
#      'key': 'eTPLdHfQZLNXNj0ytkDgsfoYb5HjzshD',
#      'md5': '35d90c56da060045d6b3c8bfd4d62809',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0295-d00.fits.fz?versionId=eTPLdHfQZLNXNj0ytkDgsfoYb5HjzshD&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=6a05516c9ffc25cb5bf6fe601be5d27e7e2e3b6555c6be29579c7dd6c3e498eb',
#      'created': '2016-08-16T10:45:55.812550Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0295-d00.fits.fz?versionId=_Aki_Ka1hbXy_1Re5AarPxZzrS_rS1hp&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=8b629829a822ca2773cf6f687756a29d112e4b936c25d380f2adb77080043ed3',
#    'filename': 'coj1m003-kb77-20160731-0295-d00.fits.fz',
#    'DATE_OBS': '2016-07-31T21:57:24.347000Z',
#    'DAY_OBS': '2016-07-31',
#    'PROPID': 'calibrate',
#    'INSTRUME': 'kb77',
#    'OBJECT': '',
#    'RLEVEL': 0,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': 299.235,
#    'FILTER': 'R',
#    'L1PUBDAT': '2016-07-31T21:57:24.347000Z',
#    'OBSTYPE': 'DARK',
#    'BLKUID': 88091929,
#    'REQNUM': None,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[52.08447052075763, -35.165802922683916],
#       [52.085004002514616, -35.43129727837312],
#       [51.75916800924969, -35.43129717147342],
#       [51.75970175168255, -35.16580281682942],
#       [52.08447052075763, -35.165802922683916]]]},
#    'related_frames': [19755594]},
#   {'id': 19755594,
#    'basename': 'coj1m003-kb77-20160731-0295-d91',
#    'observation_date': '2016-07-31T21:57:24.347000Z',
#    'observation_day': '2016-07-31',
#    'proposal_id': 'calibrate',
#    'instrument_id': 'kb77',
#    'target_name': '',
#    'reduction_level': 91,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': 299.235,
#    'primary_optical_element': 'R',
#    'public_date': '2016-07-31T21:57:24.347000Z',
#    'configuration_type': 'DARK',
#    'observation_id': 88091929,
#    'request_id': None,
#    'version_set': [{'id': 20902105,
#      'key': 'O_bmJgUNbNHWjR8Lidi.hqS7TQWvlXz4',
#      'md5': '7776945143a56e1835ec3f0d74a46791',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/processed/coj1m003-kb77-20160731-0295-d91.fits.fz?versionId=O_bmJgUNbNHWjR8Lidi.hqS7TQWvlXz4&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=f42d9879a490e942b1d291fc711524ef35f8f71835a92ee37c5555bf518e60c5',
#      'created': '2020-03-17T23:38:05.304580Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/processed/coj1m003-kb77-20160731-0295-d91.fits.fz?versionId=O_bmJgUNbNHWjR8Lidi.hqS7TQWvlXz4&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=f42d9879a490e942b1d291fc711524ef35f8f71835a92ee37c5555bf518e60c5',
#    'filename': 'coj1m003-kb77-20160731-0295-d91.fits.fz',
#    'DATE_OBS': '2016-07-31T21:57:24.347000Z',
#    'DAY_OBS': '2016-07-31',
#    'PROPID': 'calibrate',
#    'INSTRUME': 'kb77',
#    'OBJECT': '',
#    'RLEVEL': 91,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': 299.235,
#    'FILTER': 'R',
#    'L1PUBDAT': '2016-07-31T21:57:24.347000Z',
#    'OBSTYPE': 'DARK',
#    'BLKUID': 88091929,
#    'REQNUM': None,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[52.08288654171397, -35.1671020169073],
#       [52.0834096485353, -35.43000241742607],
#       [51.76076236449413, -35.430002311575834],
#       [51.761285729444495, -35.16710191208196],
#       [52.08288654171397, -35.1671020169073]]]},
#    'related_frames': [4565694, 4380129]},
#   {'id': 19755595,
#    'basename': 'coj1m003-kb77-20160731-0294-d91',
#    'observation_date': '2016-07-31T21:52:15.084000Z',
#    'observation_day': '2016-07-31',
#    'proposal_id': 'calibrate',
#    'instrument_id': 'kb77',
#    'target_name': '',
#    'reduction_level': 91,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': 299.238,
#    'primary_optical_element': 'R',
#    'public_date': '2016-07-31T21:52:15.084000Z',
#    'configuration_type': 'DARK',
#    'observation_id': 88091929,
#    'request_id': None,
#    'version_set': [{'id': 20902110,
#      'key': 'VJZVEcDXLJ2oZGS6MMjLpaYhpRQ4x74b',
#      'md5': '232a1d07605702b7b2237d43533a781c',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/processed/coj1m003-kb77-20160731-0294-d91.fits.fz?versionId=VJZVEcDXLJ2oZGS6MMjLpaYhpRQ4x74b&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=329c2ccefec9f4e9790a39c1d10e607a4a0d6ad98c63b3007403657f675d1eb8',
#      'created': '2020-03-17T23:38:06.437024Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/processed/coj1m003-kb77-20160731-0294-d91.fits.fz?versionId=VJZVEcDXLJ2oZGS6MMjLpaYhpRQ4x74b&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=329c2ccefec9f4e9790a39c1d10e607a4a0d6ad98c63b3007403657f675d1eb8',
#    'filename': 'coj1m003-kb77-20160731-0294-d91.fits.fz',
#    'DATE_OBS': '2016-07-31T21:52:15.084000Z',
#    'DAY_OBS': '2016-07-31',
#    'PROPID': 'calibrate',
#    'INSTRUME': 'kb77',
#    'OBJECT': '',
#    'RLEVEL': 91,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': 299.238,
#    'FILTER': 'R',
#    'L1PUBDAT': '2016-07-31T21:52:15.084000Z',
#    'OBSTYPE': 'DARK',
#    'BLKUID': 88091929,
#    'REQNUM': None,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[50.78945364993289, -35.1687754103202],
#       [50.789976799968876, -35.43167581079603],
#       [50.467322811406774, -35.431675704939266],
#       [50.46784621959312, -35.16877530548835],
#       [50.78945364993289, -35.1687754103202]]]},
#    'related_frames': [4565668, 4380129]},
#   {'id': 4565668,
#    'basename': 'coj1m003-kb77-20160731-0294-d00',
#    'observation_date': '2016-07-31T21:52:15.084000Z',
#    'observation_day': '2016-07-31',
#    'proposal_id': 'calibrate',
#    'instrument_id': 'kb77',
#    'target_name': '',
#    'reduction_level': 0,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': 299.238,
#    'primary_optical_element': 'R',
#    'public_date': '2016-07-31T21:52:15.084000Z',
#    'configuration_type': 'DARK',
#    'observation_id': 88091929,
#    'request_id': None,
#    'version_set': [{'id': 20902082,
#      'key': '4QeIevQlwX32xGIoyNU5tPu45NOtRyPq',
#      'md5': '4aca07928ccaeda385f25a6a9206624f',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0294-d00.fits.fz?versionId=4QeIevQlwX32xGIoyNU5tPu45NOtRyPq&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=7579df7ac982d2973522c9afb9f8422bbf540054a6071600fa7290b244973b1e',
#      'created': '2020-03-17T23:37:59.648679Z'},
#     {'id': 4901645,
#      'key': 'jFgJigRDYgxdR8JhZm88lEseAWOk3cXj',
#      'md5': 'd0a7908c124e8913bacb2aa029c864b1',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0294-d00.fits.fz?versionId=jFgJigRDYgxdR8JhZm88lEseAWOk3cXj&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=1eb0a1f1e56b34d42725d461a9c15b1ee4475c41add0a8fe85bd70fbbb284298',
#      'created': '2016-08-16T10:46:10.802190Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0294-d00.fits.fz?versionId=4QeIevQlwX32xGIoyNU5tPu45NOtRyPq&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=7579df7ac982d2973522c9afb9f8422bbf540054a6071600fa7290b244973b1e',
#    'filename': 'coj1m003-kb77-20160731-0294-d00.fits.fz',
#    'DATE_OBS': '2016-07-31T21:52:15.084000Z',
#    'DAY_OBS': '2016-07-31',
#    'PROPID': 'calibrate',
#    'INSTRUME': 'kb77',
#    'OBJECT': '',
#    'RLEVEL': 0,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': 299.238,
#    'FILTER': 'R',
#    'L1PUBDAT': '2016-07-31T21:52:15.084000Z',
#    'OBSTYPE': 'DARK',
#    'BLKUID': 88091929,
#    'REQNUM': None,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[50.791037661411536, -35.167476315966375],
#       [50.791571187240265, -35.43297067161136],
#       [50.46572842287015, -35.43297056470506],
#       [50.46626220939629, -35.16747621010531],
#       [50.791037661411536, -35.167476315966375]]]},
#    'related_frames': [19755595]},
#   {'id': 19755598,
#    'basename': 'coj1m003-kb77-20160731-0293-d91',
#    'observation_date': '2016-07-31T21:47:05.784000Z',
#    'observation_day': '2016-07-31',
#    'proposal_id': 'calibrate',
#    'instrument_id': 'kb77',
#    'target_name': '',
#    'reduction_level': 91,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': 299.235,
#    'primary_optical_element': 'R',
#    'public_date': '2016-07-31T21:47:05.784000Z',
#    'configuration_type': 'DARK',
#    'observation_id': 88091929,
#    'request_id': None,
#    'version_set': [{'id': 20902114,
#      'key': 'ugnmpA5W65SiJ1C8BtZ0XJ7Q_gZWzo0D',
#      'md5': '17a19ebdbac5fb4db87c08b819bc91c9',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/processed/coj1m003-kb77-20160731-0293-d91.fits.fz?versionId=ugnmpA5W65SiJ1C8BtZ0XJ7Q_gZWzo0D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=0dd1738d79c8197761e78d5ef0ac8f4e35a693a11d55ff061e9119a2998e34ec',
#      'created': '2020-03-17T23:38:07.074440Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/processed/coj1m003-kb77-20160731-0293-d91.fits.fz?versionId=ugnmpA5W65SiJ1C8BtZ0XJ7Q_gZWzo0D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=0dd1738d79c8197761e78d5ef0ac8f4e35a693a11d55ff061e9119a2998e34ec',
#    'filename': 'coj1m003-kb77-20160731-0293-d91.fits.fz',
#    'DATE_OBS': '2016-07-31T21:47:05.784000Z',
#    'DAY_OBS': '2016-07-31',
#    'PROPID': 'calibrate',
#    'INSTRUME': 'kb77',
#    'OBJECT': '',
#    'RLEVEL': 91,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': 299.235,
#    'FILTER': 'R',
#    'L1PUBDAT': '2016-07-31T21:47:05.784000Z',
#    'OBSTYPE': 'DARK',
#    'BLKUID': 88091929,
#    'REQNUM': None,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[49.49596009891174, -35.17041870385134],
#       [49.49648329138855, -35.433319104285005],
#       [49.173822718362935, -35.4333189984218],
#       [49.174346169011045, -35.17041859901311],
#       [49.49596009891174, -35.17041870385134]]]},
#    'related_frames': [4565669, 4380129]},
#   {'id': 4565669,
#    'basename': 'coj1m003-kb77-20160731-0293-d00',
#    'observation_date': '2016-07-31T21:47:05.784000Z',
#    'observation_day': '2016-07-31',
#    'proposal_id': 'calibrate',
#    'instrument_id': 'kb77',
#    'target_name': '',
#    'reduction_level': 0,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': 299.235,
#    'primary_optical_element': 'R',
#    'public_date': '2016-07-31T21:47:05.784000Z',
#    'configuration_type': 'DARK',
#    'observation_id': 88091929,
#    'request_id': None,
#    'version_set': [{'id': 20902086,
#      'key': 'PVNHDorVRJsgCDyyd1.mTPZRV6nbD92j',
#      'md5': '108587e2735c50faf28e8a09ffe8c205',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0293-d00.fits.fz?versionId=PVNHDorVRJsgCDyyd1.mTPZRV6nbD92j&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=68eedd71cfd90e5f9159af90e3df7515f3cd1fd8bf0400b49295d08791439707',
#      'created': '2020-03-17T23:38:00.951219Z'},
#     {'id': 4901639,
#      'key': 'xvQ3B5Rkm6ukdwAG3nkbW6VJ7JIn3uhF',
#      'md5': '0f4203bc68c6fc3066cb761a722facc3',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0293-d00.fits.fz?versionId=xvQ3B5Rkm6ukdwAG3nkbW6VJ7JIn3uhF&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=d7a9282cb7a2d608bf7535cfe2e776abbc5ae242e2620dc0e524d60d9d3653f6',
#      'created': '2016-08-16T10:45:54.345194Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0293-d00.fits.fz?versionId=PVNHDorVRJsgCDyyd1.mTPZRV6nbD92j&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=68eedd71cfd90e5f9159af90e3df7515f3cd1fd8bf0400b49295d08791439707',
#    'filename': 'coj1m003-kb77-20160731-0293-d00.fits.fz',
#    'DATE_OBS': '2016-07-31T21:47:05.784000Z',
#    'DAY_OBS': '2016-07-31',
#    'PROPID': 'calibrate',
#    'INSTRUME': 'kb77',
#    'OBJECT': '',
#    'RLEVEL': 0,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': 299.235,
#    'FILTER': 'R',
#    'L1PUBDAT': '2016-07-31T21:47:05.784000Z',
#    'OBSTYPE': 'DARK',
#    'BLKUID': 88091929,
#    'REQNUM': None,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[49.497544142244564, -35.16911960936941],
#       [49.49807771135586, -35.43461396497097],
#       [49.172228297130296, -35.434613858058164],
#       [49.172762126960144, -35.169119503501896],
#       [49.497544142244564, -35.16911960936941]]]},
#    'related_frames': [19755598]},
#   {'id': 4565654,
#    'basename': 'coj1m003-kb77-20160731-0292-d00',
#    'observation_date': '2016-07-31T21:41:56.594000Z',
#    'observation_day': '2016-07-31',
#    'proposal_id': 'calibrate',
#    'instrument_id': 'kb77',
#    'target_name': '',
#    'reduction_level': 0,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': 299.234,
#    'primary_optical_element': 'R',
#    'public_date': '2016-07-31T21:41:56.594000Z',
#    'configuration_type': 'DARK',
#    'observation_id': 88091929,
#    'request_id': None,
#    'version_set': [{'id': 20902085,
#      'key': 'eBSlmTERjDcT05XN3RlieEzx9WY46ZW2',
#      'md5': '52c8202becafe2d887640ea76f6d6452',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0292-d00.fits.fz?versionId=eBSlmTERjDcT05XN3RlieEzx9WY46ZW2&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=de4d5e157806b783088684548e9e2f9ffd577e48d3c00aaed4cd87c6ebb25055',
#      'created': '2020-03-17T23:38:00.867192Z'},
#     {'id': 4901632,
#      'key': 'AAR3kkkzi4t.V0iVyWUeHQGHQ0igG_69',
#      'md5': '3cf30a9c3015ef1307939578ede313f1',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0292-d00.fits.fz?versionId=AAR3kkkzi4t.V0iVyWUeHQGHQ0igG_69&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=1788f7ed2c6d90ed33247b12232735971488e8331cb91c0e098685de72516208',
#      'created': '2016-08-16T10:45:31.832034Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0292-d00.fits.fz?versionId=eBSlmTERjDcT05XN3RlieEzx9WY46ZW2&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=de4d5e157806b783088684548e9e2f9ffd577e48d3c00aaed4cd87c6ebb25055',
#    'filename': 'coj1m003-kb77-20160731-0292-d00.fits.fz',
#    'DATE_OBS': '2016-07-31T21:41:56.594000Z',
#    'DAY_OBS': '2016-07-31',
#    'PROPID': 'calibrate',
#    'INSTRUME': 'kb77',
#    'OBJECT': '',
#    'RLEVEL': 0,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': 299.234,
#    'FILTER': 'R',
#    'L1PUBDAT': '2016-07-31T21:41:56.594000Z',
#    'OBSTYPE': 'DARK',
#    'BLKUID': 88091929,
#    'REQNUM': None,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[48.20430006064637, -35.170731502898256],
#       [48.2048336722166, -35.43622585845721],
#       [47.878977734676184, -35.43622575153804],
#       [47.87951160698572, -35.17073139702442],
#       [48.20430006064637, -35.170731502898256]]]},
#    'related_frames': [19755597]},
#   {'id': 19755597,
#    'basename': 'coj1m003-kb77-20160731-0292-d91',
#    'observation_date': '2016-07-31T21:41:56.594000Z',
#    'observation_day': '2016-07-31',
#    'proposal_id': 'calibrate',
#    'instrument_id': 'kb77',
#    'target_name': '',
#    'reduction_level': 91,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': 299.234,
#    'primary_optical_element': 'R',
#    'public_date': '2016-07-31T21:41:56.594000Z',
#    'configuration_type': 'DARK',
#    'observation_id': 88091929,
#    'request_id': None,
#    'version_set': [{'id': 20902113,
#      'key': 'ryBQPlmY6dYW8C1tOiIrSfzcITmkgE40',
#      'md5': '77a27a098e1fa75cd44b898c255509f8',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/processed/coj1m003-kb77-20160731-0292-d91.fits.fz?versionId=ryBQPlmY6dYW8C1tOiIrSfzcITmkgE40&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=a09ff5441829bf827f3344a23befef2bd4427c21493a19ca6c7e9d14ea925266',
#      'created': '2020-03-17T23:38:06.906949Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/processed/coj1m003-kb77-20160731-0292-d91.fits.fz?versionId=ryBQPlmY6dYW8C1tOiIrSfzcITmkgE40&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=a09ff5441829bf827f3344a23befef2bd4427c21493a19ca6c7e9d14ea925266',
#    'filename': 'coj1m003-kb77-20160731-0292-d91.fits.fz',
#    'DATE_OBS': '2016-07-31T21:41:56.594000Z',
#    'DAY_OBS': '2016-07-31',
#    'PROPID': 'calibrate',
#    'INSTRUME': 'kb77',
#    'OBJECT': '',
#    'RLEVEL': 91,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': 299.234,
#    'FILTER': 'R',
#    'L1PUBDAT': '2016-07-31T21:41:56.594000Z',
#    'OBSTYPE': 'DARK',
#    'BLKUID': 88091929,
#    'REQNUM': None,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[48.20271598606552, -35.17203059750585],
#       [48.20323922017555, -35.43493099789814],
#       [47.88057218798267, -35.434930892028625],
#       [47.88109568028454, -35.17203049266136],
#       [48.20271598606552, -35.17203059750585]]]},
#    'related_frames': [4565654, 4380129]},
#   {'id': 19755601,
#    'basename': 'coj1m003-kb77-20160731-0291-d91',
#    'observation_date': '2016-07-31T21:36:47.347000Z',
#    'observation_day': '2016-07-31',
#    'proposal_id': 'calibrate',
#    'instrument_id': 'kb77',
#    'target_name': '',
#    'reduction_level': 91,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': 299.233,
#    'primary_optical_element': 'R',
#    'public_date': '2016-07-31T21:36:47.347000Z',
#    'configuration_type': 'DARK',
#    'observation_id': 88091929,
#    'request_id': None,
#    'version_set': [{'id': 20902117,
#      'key': 'eZSGvqXjZrpkY4UWbYBuYx0ODMrbOQ8b',
#      'md5': '6d9ad1caa50e892c73eda7924cd59ee1',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/processed/coj1m003-kb77-20160731-0291-d91.fits.fz?versionId=eZSGvqXjZrpkY4UWbYBuYx0ODMrbOQ8b&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=2d5c3bca7b08e510fddcb99566b5163ecded08345c5dfa0d4cc8291b70aa575f',
#      'created': '2020-03-17T23:38:10.232446Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/processed/coj1m003-kb77-20160731-0291-d91.fits.fz?versionId=eZSGvqXjZrpkY4UWbYBuYx0ODMrbOQ8b&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=2d5c3bca7b08e510fddcb99566b5163ecded08345c5dfa0d4cc8291b70aa575f',
#    'filename': 'coj1m003-kb77-20160731-0291-d91.fits.fz',
#    'DATE_OBS': '2016-07-31T21:36:47.347000Z',
#    'DAY_OBS': '2016-07-31',
#    'PROPID': 'calibrate',
#    'INSTRUME': 'kb77',
#    'OBJECT': '',
#    'RLEVEL': 91,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': 299.233,
#    'FILTER': 'R',
#    'L1PUBDAT': '2016-07-31T21:36:47.347000Z',
#    'OBSTYPE': 'DARK',
#    'BLKUID': 88091929,
#    'REQNUM': None,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[46.907852514543436, -35.17361269127739],
#       [46.9083757895202, -35.43651309162908],
#       [46.585702417074096, -35.43651298575339],
#       [46.58622595026287, -35.17361258642675],
#       [46.907852514543436, -35.17361269127739]]]},
#    'related_frames': [4565655, 4380129]},
#   {'id': 4565655,
#    'basename': 'coj1m003-kb77-20160731-0291-d00',
#    'observation_date': '2016-07-31T21:36:47.347000Z',
#    'observation_day': '2016-07-31',
#    'proposal_id': 'calibrate',
#    'instrument_id': 'kb77',
#    'target_name': '',
#    'reduction_level': 0,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': 299.233,
#    'primary_optical_element': 'R',
#    'public_date': '2016-07-31T21:36:47.347000Z',
#    'configuration_type': 'DARK',
#    'observation_id': 88091929,
#    'request_id': None,
#    'version_set': [{'id': 20902083,
#      'key': '9irbZDHUxB3G.DybbFApRCRXkWNLD5Zk',
#      'md5': '62a3ccfe866532f7f5265fd4dd828d64',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0291-d00.fits.fz?versionId=9irbZDHUxB3G.DybbFApRCRXkWNLD5Zk&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=6fdc19b7f64520253e3554aab3441050452b7ed654e3e03d9cd2802cf4bcfd8e',
#      'created': '2020-03-17T23:37:59.980368Z'},
#     {'id': 4901631,
#      'key': '53TNcask7fIYUg.HsOzzt6DaKH.84BQK',
#      'md5': 'a1f8c449c15ca4617c96a921651b65ca',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0291-d00.fits.fz?versionId=53TNcask7fIYUg.HsOzzt6DaKH.84BQK&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=ab11c81165245e7a8cb8cc448cc8485a9e622395aed9e5501c3f2e59e2ef6c94',
#      'created': '2016-08-16T10:45:27.225764Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0291-d00.fits.fz?versionId=9irbZDHUxB3G.DybbFApRCRXkWNLD5Zk&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=6fdc19b7f64520253e3554aab3441050452b7ed654e3e03d9cd2802cf4bcfd8e',
#    'filename': 'coj1m003-kb77-20160731-0291-d00.fits.fz',
#    'DATE_OBS': '2016-07-31T21:36:47.347000Z',
#    'DAY_OBS': '2016-07-31',
#    'PROPID': 'calibrate',
#    'INSTRUME': 'kb77',
#    'OBJECT': '',
#    'RLEVEL': 0,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': 299.233,
#    'FILTER': 'R',
#    'L1PUBDAT': '2016-07-31T21:36:47.347000Z',
#    'OBSTYPE': 'DARK',
#    'BLKUID': 88091929,
#    'REQNUM': None,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[46.90943661979703, -35.17231359654646],
#       [46.90997027304452, -35.43780795206359],
#       [46.58410793228424, -35.43780784513817],
#       [46.58464184629141, -35.17231349066641],
#       [46.90943661979703, -35.17231359654646]]]},
#    'related_frames': [19755601]},
#   {'id': 4565569,
#    'basename': 'coj1m003-kb77-20160731-0290-b00',
#    'observation_date': '2016-07-31T21:36:26.124000Z',
#    'observation_day': '2016-07-31',
#    'proposal_id': 'calibrate',
#    'instrument_id': 'kb77',
#    'target_name': '',
#    'reduction_level': 0,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': -0.583,
#    'primary_optical_element': 'R',
#    'public_date': '2016-07-31T21:36:26.124000Z',
#    'configuration_type': 'BIAS',
#    'observation_id': 88091929,
#    'request_id': None,
#    'version_set': [{'id': 20902101,
#      'key': 'YjtJCmfwEXZqKa1ony4.tQEgqCWvd9Wy',
#      'md5': 'b4c27611289e1314b0ce62255c7c0f5e',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0290-b00.fits.fz?versionId=YjtJCmfwEXZqKa1ony4.tQEgqCWvd9Wy&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=f040e3d1233990af809eea8ab69bc24cd0fe76786967eefd159ce30c82e16e19',
#      'created': '2020-03-17T23:38:04.247137Z'},
#     {'id': 4901637,
#      'key': 'a.LsfsqW8.FRBmXLOzBoUWIX.K174xLi',
#      'md5': 'b3996ae3289359481f83af31c4939a0c',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0290-b00.fits.fz?versionId=a.LsfsqW8.FRBmXLOzBoUWIX.K174xLi&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=6c7cfb5c4e031e2c9a8c666272f44afcf43e7ed79176e5a771e4a2c66a85f85f',
#      'created': '2016-08-16T10:45:48.274523Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0290-b00.fits.fz?versionId=YjtJCmfwEXZqKa1ony4.tQEgqCWvd9Wy&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=f040e3d1233990af809eea8ab69bc24cd0fe76786967eefd159ce30c82e16e19',
#    'filename': 'coj1m003-kb77-20160731-0290-b00.fits.fz',
#    'DATE_OBS': '2016-07-31T21:36:26.124000Z',
#    'DAY_OBS': '2016-07-31',
#    'PROPID': 'calibrate',
#    'INSTRUME': 'kb77',
#    'OBJECT': '',
#    'RLEVEL': 0,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': -0.583,
#    'FILTER': 'R',
#    'L1PUBDAT': '2016-07-31T21:36:26.124000Z',
#    'OBSTYPE': 'BIAS',
#    'BLKUID': 88091929,
#    'REQNUM': None,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[46.825714363531645, -35.17224750243253],
#       [46.82624910297983, -35.43801145323789],
#       [46.50005504078085, -35.43801134612055],
#       [46.500590041455574, -35.1722473963635],
#       [46.825714363531645, -35.17224750243253]]]},
#    'related_frames': []},
#   {'id': 4565566,
#    'basename': 'coj1m003-kb77-20160731-0289-b00',
#    'observation_date': '2016-07-31T21:36:11.374000Z',
#    'observation_day': '2016-07-31',
#    'proposal_id': 'calibrate',
#    'instrument_id': 'kb77',
#    'target_name': '',
#    'reduction_level': 0,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': -0.583,
#    'primary_optical_element': 'R',
#    'public_date': '2016-07-31T21:36:11.374000Z',
#    'configuration_type': 'BIAS',
#    'observation_id': 88091929,
#    'request_id': None,
#    'version_set': [{'id': 20902094,
#      'key': 'MGHQxbRu4YZQ.BAwcWdVl5Y6J3tq_ztX',
#      'md5': '7b6a804245b73e94be706379bcf2a81a',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0289-b00.fits.fz?versionId=MGHQxbRu4YZQ.BAwcWdVl5Y6J3tq_ztX&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=03759f234bf7944703569d3a779af0abc93beed06390dd7bed216271d0aa3746',
#      'created': '2020-03-17T23:38:02.749737Z'},
#     {'id': 4901634,
#      'key': 'x6KKocc73OwL3bDuObDN6Xu9BrGHDKyJ',
#      'md5': '74dfc827df0564e9849316a45fb05346',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0289-b00.fits.fz?versionId=x6KKocc73OwL3bDuObDN6Xu9BrGHDKyJ&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=0f6dd6f9a75ff8b04c4582bed1affaabae4b904062416d84396f78fc7389cbad',
#      'created': '2016-08-16T10:45:36.204890Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0289-b00.fits.fz?versionId=MGHQxbRu4YZQ.BAwcWdVl5Y6J3tq_ztX&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=03759f234bf7944703569d3a779af0abc93beed06390dd7bed216271d0aa3746',
#    'filename': 'coj1m003-kb77-20160731-0289-b00.fits.fz',
#    'DATE_OBS': '2016-07-31T21:36:11.374000Z',
#    'DAY_OBS': '2016-07-31',
#    'PROPID': 'calibrate',
#    'INSTRUME': 'kb77',
#    'OBJECT': '',
#    'RLEVEL': 0,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': -0.583,
#    'FILTER': 'R',
#    'L1PUBDAT': '2016-07-31T21:36:11.374000Z',
#    'OBSTYPE': 'BIAS',
#    'BLKUID': 88091929,
#    'REQNUM': None,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[46.76388801285033, -35.172322202132015],
#       [46.76442275427042, -35.4380861529354],
#       [46.438228389416345, -35.43808604581776],
#       [46.43876339206395, -35.17232209606269],
#       [46.76388801285033, -35.172322202132015]]]},
#    'related_frames': []},
#   {'id': 4565564,
#    'basename': 'coj1m003-kb77-20160731-0288-b00',
#    'observation_date': '2016-07-31T21:35:56.614000Z',
#    'observation_day': '2016-07-31',
#    'proposal_id': 'calibrate',
#    'instrument_id': 'kb77',
#    'target_name': '',
#    'reduction_level': 0,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': -0.583,
#    'primary_optical_element': 'R',
#    'public_date': '2016-07-31T21:35:56.614000Z',
# ...
#    'filename': 'coj1m003-kb77-20160729-0187-x00.fits.fz',
#    'DATE_OBS': '2016-07-29T19:28:37.931000Z',
#    'DAY_OBS': '2016-07-29',
#    'PROPID': 'auto_focus',
#    'INSTRUME': 'kb77',
#    'OBJECT': 'auto_focus',
#    'RLEVEL': 0,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': 9.697,
#    'FILTER': 'rp',
#    'L1PUBDAT': '2016-07-29T19:28:37.931000Z',
#    'OBSTYPE': 'EXPERIMENTAL',
#    'BLKUID': 88035149,
#    'REQNUM': 668956,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[12.61598216498692, -24.867213471739085],
#       [12.61629857604388, -25.132708029579213],
#       [12.323039992958892, -25.132707959092993],
#       [12.323356558624667, -24.86721340210048],
#       [12.61598216498692, -24.867213471739085]]]},
#    'related_frames': []},
#   {'id': 19440760,
#    'basename': 'coj1m003-kb77-20160729-0186-x00',
#    'observation_date': '2016-07-29T19:28:00.651000Z',
#    'observation_day': '2016-07-29',
#    'proposal_id': 'auto_focus',
#    'instrument_id': 'kb77',
#    'target_name': 'auto_focus',
#    'reduction_level': 0,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': 9.697,
#    'primary_optical_element': 'rp',
#    'public_date': '2016-07-29T19:28:00.651000Z',
#    'configuration_type': 'EXPERIMENTAL',
#    'observation_id': 88035149,
#    'request_id': 668956,
#    'version_set': [{'id': 20421594,
#      'key': 'r11egMUXHzof.4QxqsA4.aQcGhiojA7.',
#      'md5': '1cf084a9967eca00c4cfdad6469f5a79',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160729/raw/coj1m003-kb77-20160729-0186-x00.fits.fz?versionId=r11egMUXHzof.4QxqsA4.aQcGhiojA7.&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120810Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=bf9b041d1eb94fdb66afb15beb531b2bc6a230280deb8ac1fc872fb1e9c95512',
#      'created': '2020-03-12T02:00:51.336926Z'},
#     {'id': 20421525,
#      'key': 'quVD0X.W9.LpTfVYd6re0fo3jrQDtpmo',
#      'md5': 'd6e5543bed47814e15e212acbdb2ee66',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160729/raw/coj1m003-kb77-20160729-0186-x00.fits.fz?versionId=quVD0X.W9.LpTfVYd6re0fo3jrQDtpmo&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120810Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=bdd77fd051f63a6f8910070901ee42d5db51cde8df54b3bf6cab70a5af82eff6',
#      'created': '2020-03-12T02:00:17.989041Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160729/raw/coj1m003-kb77-20160729-0186-x00.fits.fz?versionId=r11egMUXHzof.4QxqsA4.aQcGhiojA7.&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120810Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=bf9b041d1eb94fdb66afb15beb531b2bc6a230280deb8ac1fc872fb1e9c95512',
#    'filename': 'coj1m003-kb77-20160729-0186-x00.fits.fz',
#    'DATE_OBS': '2016-07-29T19:28:00.651000Z',
#    'DAY_OBS': '2016-07-29',
#    'PROPID': 'auto_focus',
#    'INSTRUME': 'kb77',
#    'OBJECT': 'auto_focus',
#    'RLEVEL': 0,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': 9.697,
#    'FILTER': 'rp',
#    'L1PUBDAT': '2016-07-29T19:28:00.651000Z',
#    'OBSTYPE': 'EXPERIMENTAL',
#    'BLKUID': 88035149,
#    'REQNUM': 668956,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[12.61598216498692, -24.867213471739085],
#       [12.61629857604388, -25.132708029579213],
#       [12.323039992958892, -25.132707959092993],
#       [12.323356558624667, -24.86721340210048],
#       [12.61598216498692, -24.867213471739085]]]},
#    'related_frames': []},
#   {'id': 19440747,
#    'basename': 'coj1m003-kb77-20160729-0185-x00',
#    'observation_date': '2016-07-29T19:27:18.360000Z',
#    'observation_day': '2016-07-29',
#    'proposal_id': 'auto_focus',
#    'instrument_id': 'kb77',
#    'target_name': 'auto_focus',
#    'reduction_level': 0,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': 9.698,
#    'primary_optical_element': 'rp',
#    'public_date': '2016-07-29T19:27:18.360000Z',
#    'configuration_type': 'EXPERIMENTAL',
#    'observation_id': 88035149,
#    'request_id': 668956,
#    'version_set': [{'id': 20421581,
#      'key': 'tgKUCCpFKQUMMbP1H9E1dwAUYrjBgU.S',
#      'md5': '66dfeb7daf134ef6c362eb0a43191c55',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160729/raw/coj1m003-kb77-20160729-0185-x00.fits.fz?versionId=tgKUCCpFKQUMMbP1H9E1dwAUYrjBgU.S&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120810Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=915c19920bb5de974dff86f8154dd6c5bd0fc503626fc1aeb19ed2ccfc7cde50',
#      'created': '2020-03-12T02:00:46.534426Z'},
#     {'id': 20421507,
#      'key': 'O9cgvMDHikkR.sAulELSKvHUSXqz2rzq',
#      'md5': '15956dae66d0e7b4ff689ff8697bedc3',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160729/raw/coj1m003-kb77-20160729-0185-x00.fits.fz?versionId=O9cgvMDHikkR.sAulELSKvHUSXqz2rzq&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120810Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=abcc3c5d4321d335faf2d82b3bc4773fbad260b3e9ee83edb2a24b4546e88fb6',
#      'created': '2020-03-12T02:00:11.435913Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160729/raw/coj1m003-kb77-20160729-0185-x00.fits.fz?versionId=tgKUCCpFKQUMMbP1H9E1dwAUYrjBgU.S&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120810Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=915c19920bb5de974dff86f8154dd6c5bd0fc503626fc1aeb19ed2ccfc7cde50',
#    'filename': 'coj1m003-kb77-20160729-0185-x00.fits.fz',
#    'DATE_OBS': '2016-07-29T19:27:18.360000Z',
#    'DAY_OBS': '2016-07-29',
#    'PROPID': 'auto_focus',
#    'INSTRUME': 'kb77',
#    'OBJECT': 'auto_focus',
#    'RLEVEL': 0,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': 9.698,
#    'FILTER': 'rp',
#    'L1PUBDAT': '2016-07-29T19:27:18.360000Z',
#    'OBSTYPE': 'EXPERIMENTAL',
#    'BLKUID': 88035149,
#    'REQNUM': 668956,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[12.61598216498692, -24.867213471739085],
#       [12.61629857604388, -25.132708029579213],
#       [12.323039992958892, -25.132707959092993],
#       [12.323356558624667, -24.86721340210048],
#       [12.61598216498692, -24.867213471739085]]]},
#    'related_frames': []},
#   {'id': 19440733,
#    'basename': 'coj1m003-kb77-20160729-0184-x00',
#    'observation_date': '2016-07-29T19:26:46.121000Z',
#    'observation_day': '2016-07-29',
#    'proposal_id': 'auto_focus',
#    'instrument_id': 'kb77',
#    'target_name': 'auto_focus',
#    'reduction_level': 0,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': 9.697,
#    'primary_optical_element': 'rp',
#    'public_date': '2016-07-29T19:26:46.121000Z',
#    'configuration_type': 'EXPERIMENTAL',
#    'observation_id': 88035149,
#    'request_id': 668956,
#    'version_set': [{'id': 20421572,
#      'key': 'ScocBvPlx5WKh4lhaovyz5vc9_hSCYBw',
#      'md5': '1e9506f71fb9865e3e97c89a77d2829f',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160729/raw/coj1m003-kb77-20160729-0184-x00.fits.fz?versionId=ScocBvPlx5WKh4lhaovyz5vc9_hSCYBw&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120810Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=6af96d28eb217ed32d05f5b164ec16ae045b08047351d38d8b5c0ff63c63c0ae',
#      'created': '2020-03-12T02:00:43.757408Z'},
#     {'id': 20421494,
#      'key': 'Sgq.w5gA0Qpzp0RGdYDx4ZCEMD3wL8ng',
#      'md5': 'afb04ab7d0547d5c65349bd5eae92164',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160729/raw/coj1m003-kb77-20160729-0184-x00.fits.fz?versionId=Sgq.w5gA0Qpzp0RGdYDx4ZCEMD3wL8ng&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120810Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=a2cf4c54f9aa012314210c42ac9c64e42d4c0fcbbf67c647270276a001b38129',
#      'created': '2020-03-12T02:00:10.155999Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160729/raw/coj1m003-kb77-20160729-0184-x00.fits.fz?versionId=ScocBvPlx5WKh4lhaovyz5vc9_hSCYBw&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120810Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=6af96d28eb217ed32d05f5b164ec16ae045b08047351d38d8b5c0ff63c63c0ae',
#    'filename': 'coj1m003-kb77-20160729-0184-x00.fits.fz',
#    'DATE_OBS': '2016-07-29T19:26:46.121000Z',
#    'DAY_OBS': '2016-07-29',
#    'PROPID': 'auto_focus',
#    'INSTRUME': 'kb77',
#    'OBJECT': 'auto_focus',
#    'RLEVEL': 0,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': 9.697,
#    'FILTER': 'rp',
#    'L1PUBDAT': '2016-07-29T19:26:46.121000Z',
#    'OBSTYPE': 'EXPERIMENTAL',
#    'BLKUID': 88035149,
#    'REQNUM': 668956,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[12.61598216498692, -24.867213471739085],
#       [12.61629857604388, -25.132708029579213],
#       [12.323039992958892, -25.132707959092993],
#       [12.323356558624667, -24.86721340210048],
#       [12.61598216498692, -24.867213471739085]]]},
#    'related_frames': []},
#   {'id': 19440740,
#    'basename': 'coj1m003-kb77-20160729-0183-x00',
#    'observation_date': '2016-07-29T19:26:08.824000Z',
#    'observation_day': '2016-07-29',
#    'proposal_id': 'auto_focus',
#    'instrument_id': 'kb77',
#    'target_name': 'auto_focus',
#    'reduction_level': 0,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': 9.693,
#    'primary_optical_element': 'rp',
#    'public_date': '2016-07-29T19:26:08.824000Z',
#    'configuration_type': 'EXPERIMENTAL',
#    'observation_id': 88035149,
#    'request_id': 668956,
#    'version_set': [{'id': 20421577,
#      'key': 'fPqwfjBASgBQuRH2gjpKlMDkj8ME6lsy',
#      'md5': '7451e417f5207613961bf6d052dffc6a',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160729/raw/coj1m003-kb77-20160729-0183-x00.fits.fz?versionId=fPqwfjBASgBQuRH2gjpKlMDkj8ME6lsy&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120810Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=05358c6641140ac9bca055f7b75822101246ba522b113ab6aafc8f08c1ba5359',
#      'created': '2020-03-12T02:00:44.505858Z'},
#     {'id': 20421500,
#      'key': 'sVPf5_bGH39Yg2TJxRgRlQDZkQ.Rj5kW',
#      'md5': 'fabd3284321d674dc91352963c598964',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160729/raw/coj1m003-kb77-20160729-0183-x00.fits.fz?versionId=sVPf5_bGH39Yg2TJxRgRlQDZkQ.Rj5kW&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120810Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=e44816b1e1285e1f2a8e897a32b29e7eb73bf078dfb4787f85f0a2a343c08bb8',
#      'created': '2020-03-12T02:00:10.386635Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160729/raw/coj1m003-kb77-20160729-0183-x00.fits.fz?versionId=fPqwfjBASgBQuRH2gjpKlMDkj8ME6lsy&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120810Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=05358c6641140ac9bca055f7b75822101246ba522b113ab6aafc8f08c1ba5359',
#    'filename': 'coj1m003-kb77-20160729-0183-x00.fits.fz',
#    'DATE_OBS': '2016-07-29T19:26:08.824000Z',
#    'DAY_OBS': '2016-07-29',
#    'PROPID': 'auto_focus',
#    'INSTRUME': 'kb77',
#    'OBJECT': 'auto_focus',
#    'RLEVEL': 0,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': 9.693,
#    'FILTER': 'rp',
#    'L1PUBDAT': '2016-07-29T19:26:08.824000Z',
#    'OBSTYPE': 'EXPERIMENTAL',
#    'BLKUID': 88035149,
#    'REQNUM': 668956,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[12.61598216498692, -24.867213471739085],
#       [12.61629857604388, -25.132708029579213],
#       [12.323039992958892, -25.132707959092993],
#       [12.323356558624667, -24.86721340210048],
#       [12.61598216498692, -24.867213471739085]]]},
#    'related_frames': []},
#   {'id': 19440735,
#    'basename': 'coj1m003-kb77-20160729-0182-x00',
#    'observation_date': '2016-07-29T19:25:31.612000Z',
#    'observation_day': '2016-07-29',
#    'proposal_id': 'auto_focus',
#    'instrument_id': 'kb77',
#    'target_name': 'auto_focus',
#    'reduction_level': 0,
#    'site_id': 'coj',
#    'telescope_id': '1m0a',
#    'exposure_time': 9.695,
#    'primary_optical_element': 'rp',
#    'public_date': '2016-07-29T19:25:31.612000Z',
#    'configuration_type': 'EXPERIMENTAL',
#    'observation_id': 88035149,
#    'request_id': 668956,
#    'version_set': [{'id': 20421586,
#      'key': 'm5qS2RNKtO5dIFQRh32HZMsEhlyI4GVP',
#      'md5': 'bd056337d2c3c0f89ff0689c6eb45cb7',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160729/raw/coj1m003-kb77-20160729-0182-x00.fits.fz?versionId=m5qS2RNKtO5dIFQRh32HZMsEhlyI4GVP&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120810Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=062a8114e6ede5ac5a61cd2f14548caa7abfd664b8daceb4ba9bc09c2f0e93a1',
#      'created': '2020-03-12T02:00:48.796896Z'},
#     {'id': 20421495,
#      'key': '49xKol7jIrvbm2vsnK248DXbtZEmiRCW',
#      'md5': '77d73c7986f033b0f4bc0ea37a8fcf98',
#      'extension': '.fits.fz',
#      'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160729/raw/coj1m003-kb77-20160729-0182-x00.fits.fz?versionId=49xKol7jIrvbm2vsnK248DXbtZEmiRCW&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120810Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=a03dd27a26e0358502d4bc38c311e1c8ccf7bef5fc7b6440515db4048c707274',
#      'created': '2020-03-12T02:00:10.194755Z'}],
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160729/raw/coj1m003-kb77-20160729-0182-x00.fits.fz?versionId=m5qS2RNKtO5dIFQRh32HZMsEhlyI4GVP&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120810Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=062a8114e6ede5ac5a61cd2f14548caa7abfd664b8daceb4ba9bc09c2f0e93a1',
#    'filename': 'coj1m003-kb77-20160729-0182-x00.fits.fz',
#    'DATE_OBS': '2016-07-29T19:25:31.612000Z',
#    'DAY_OBS': '2016-07-29',
#    'PROPID': 'auto_focus',
#    'INSTRUME': 'kb77',
#    'OBJECT': 'auto_focus',
#    'RLEVEL': 0,
#    'SITEID': 'coj',
#    'TELID': '1m0a',
#    'EXPTIME': 9.695,
#    'FILTER': 'rp',
#    'L1PUBDAT': '2016-07-29T19:25:31.612000Z',
#    'OBSTYPE': 'EXPERIMENTAL',
#    'BLKUID': 88035149,
#    'REQNUM': 668956,
#    'area': {'type': 'Polygon',
#     'coordinates': [[[12.61598216498692, -24.867213471739085],
#       [12.61629857604388, -25.132708029579213],
#       [12.323039992958892, -25.132707959092993],
#       [12.323356558624667, -24.86721340210048],
#       [12.61598216498692, -24.867213471739085]]]},
#    'related_frames': []}],
#  'count_estimated': False}

# %%
data.keys()
# Out:
# dict_keys(['count', 'next', 'previous', 'results', 'count_estimated'])

# %%
dd = data["results"]

# %%
len(dd)
# Out:
# 1000

# %%
dd[0]
# Out:
# {'id': 4565855,
#  'basename': 'coj1m003-kb77-20160731-0300-d00',
#  'observation_date': '2016-07-31T22:23:39.951000Z',
#  'observation_day': '2016-07-31',
#  'proposal_id': 'calibrate',
#  'instrument_id': 'kb77',
#  'target_name': '',
#  'reduction_level': 0,
#  'site_id': 'coj',
#  'telescope_id': '1m0a',
#  'exposure_time': 299.236,
#  'primary_optical_element': 'R',
#  'public_date': '2016-07-31T22:23:39.951000Z',
#  'configuration_type': 'DARK',
#  'observation_id': 88091929,
#  'request_id': None,
#  'version_set': [{'id': 20902118,
#    'key': 'pVCuzTZubTZ3Bhl7WWI3qRvn1eJVeI7N',
#    'md5': '92034d38d371c1f25c8dca59994661a8',
#    'extension': '.fits.fz',
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0300-d00.fits.fz?versionId=pVCuzTZubTZ3Bhl7WWI3qRvn1eJVeI7N&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=a516db356b808ab509bed8eac77f4a0db3cccc2c2d582c49fc564b71236e04fe',
#    'created': '2020-03-17T23:38:10.541599Z'},
#   {'id': 4901659,
#    'key': 'W7ij4PX3lzzTuVMjxOK6pY2NiY5lcoEl',
#    'md5': '56abcf89c116c9f3a8f5c93b4f1775b3',
#    'extension': '.fits.fz',
#    'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0300-d00.fits.fz?versionId=W7ij4PX3lzzTuVMjxOK6pY2NiY5lcoEl&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=b2f74294347acace0bf0907f812450a443e44b9e2ec1851cc81ddac3230d06ef',
#    'created': '2016-08-16T10:46:28.825103Z'}],
#  'url': 'https://archive-lco-global.s3.us-west-2.amazonaws.com/coj/kb77/20160731/raw/coj1m003-kb77-20160731-0300-d00.fits.fz?versionId=pVCuzTZubTZ3Bhl7WWI3qRvn1eJVeI7N&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6FT4CXR464A32PW2%2F20240214%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240214T120806Z&X-Amz-Expires=172800&X-Amz-SignedHeaders=host&X-Amz-Signature=a516db356b808ab509bed8eac77f4a0db3cccc2c2d582c49fc564b71236e04fe',
#  'filename': 'coj1m003-kb77-20160731-0300-d00.fits.fz',
#  'DATE_OBS': '2016-07-31T22:23:39.951000Z',
#  'DAY_OBS': '2016-07-31',
#  'PROPID': 'calibrate',
#  'INSTRUME': 'kb77',
#  'OBJECT': '',
#  'RLEVEL': 0,
#  'SITEID': 'coj',
#  'TELID': '1m0a',
#  'EXPTIME': 299.236,
#  'FILTER': 'R',
#  'L1PUBDAT': '2016-07-31T22:23:39.951000Z',
#  'OBSTYPE': 'DARK',
#  'BLKUID': 88091929,
#  'REQNUM': None,
#  'area': {'type': 'Polygon',
#   'coordinates': [[[58.67261764790169, -35.156675265068095],
#     [58.67315197643579, -35.42243921628618],
#     [58.34702098272599, -35.42243910923045],
#     [58.3475555722859, -35.15667515906027],
#     [58.67261764790169, -35.156675265068095]]]},
#  'related_frames': []}

# %%
df = pd.DataFrame(dd)

# %%
df.columns
# Out:
# Index(['id', 'basename', 'observation_date', 'observation_day', 'proposal_id',
#        'instrument_id', 'target_name', 'reduction_level', 'site_id',
#        'telescope_id', 'exposure_time', 'primary_optical_element',
#        'public_date', 'configuration_type', 'observation_id', 'request_id',
#        'version_set', 'url', 'filename', 'DATE_OBS', 'DAY_OBS', 'PROPID',
#        'INSTRUME', 'OBJECT', 'RLEVEL', 'SITEID', 'TELID', 'EXPTIME', 'FILTER',
#        'L1PUBDAT', 'OBSTYPE', 'BLKUID', 'REQNUM', 'area', 'related_frames'],
#       dtype='object')
